# %%
import tensorflow as tf
import pandas as pd
import os
data=pd.DataFrame()
paths=[]
for filename in os.listdir("Dataset"):
    paths.append(os.path.join("Dataset", filename))
data["images"]=paths
