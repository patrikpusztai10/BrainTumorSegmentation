# %%
import tensorflow as tf

train=tf.keras.utils.image_dataset_from_directory(
    "Dataset",
    validation_split=0.2,
    seed=123,
    subset="training",
)
validation=tf.keras.utils.image_dataset_from_directory(
    "Dataset",
    validation_split=0.2,
    seed=123,
    subset="validation",
)
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\D'
# <>:10: SyntaxWarning: invalid escape sequence '\D'
# <>:4: SyntaxWarning: invalid escape sequence '\D'
# <>:10: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\Patrik P\AppData\Local\Temp\ipykernel_10560\1833137275.py:4: SyntaxWarning: invalid escape sequence '\D'
#   "BrainTumorSegmentation\Dataset",
# C:\Users\Patrik P\AppData\Local\Temp\ipykernel_10560\1833137275.py:10: SyntaxWarning: invalid escape sequence '\D'
#   "BrainTumorSegmentation\Dataset",
# C:\Users\Patrik P\AppData\Local\Temp\ipykernel_10560\1833137275.py:4: SyntaxWarning: invalid escape sequence '\D'
#   "BrainTumorSegmentation\Dataset",
# C:\Users\Patrik P\AppData\Local\Temp\ipykernel_10560\1833137275.py:10: SyntaxWarning: invalid escape sequence '\D'
#   "BrainTumorSegmentation\Dataset",
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 import tensorflow as tf
# ----> 3 train=tf.keras.utils.image_dataset_from_directory(
#       4     "BrainTumorSegmentation\Dataset",
#       5     validation_split=0.2,
#       6     seed=123,
#       7     subset="training",
#       8 )
#       9 validation=tf.keras.utils.image_dataset_from_directory(
#      10     "BrainTumorSegmentation\Dataset",
#      11     validation_split=0.2,
#      12     seed=123,
#      13     subset="validation",
#      14 )
#
# File c:\Users\Patrik P\Downloads\BrainTumorSegmentation\.venv\Lib\site-packages\keras\src\utils\image_dataset_utils.py:265, in image_dataset_from_directory(directory, labels, label_mode, class_names, color_mode, batch_size, image_size, shuffle, seed, validation_split, subset, interpolation, follow_links, crop_to_aspect_ratio, pad_to_aspect_ratio, data_format, format, verbose)
#     263 if seed is None:
#     264     seed = np.random.randint(1e6)
# --> 265 image_paths, labels, class_names = dataset_utils.index_directory(
#     266     directory,
#     267     labels,
#     268     formats=ALLOWLIST_FORMATS,
#     269     class_names=class_names,
#     270     shuffle=shuffle,
#     271     seed=seed,
#     272     follow_links=follow_links,
#     273     verbose=verbose,
#     274 )
#     276 if label_mode == "binary" and len(class_names) != 2:
#     277     raise ValueError(
#     278         'When passing `label_mode="binary"`, there must be exactly 2 '
#     279         f"class_names. Received: class_names={class_names}"
#     280     )
#
# File c:\Users\Patrik P\Downloads\BrainTumorSegmentation\.venv\Lib\site-packages\keras\src\utils\dataset_utils.py:743, in index_directory(directory, labels, formats, class_names, shuffle, seed, follow_links, verbose)
#     741 if labels == "inferred":
#     742     subdirs = []
# --> 743     for subdir in sorted(os_module.listdir(directory)):
#     744         if path_module.isdir(path_module.join(directory, subdir)):
#     745             if not subdir.startswith("."):
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'BrainTumorSegmentation\\Dataset'

# %%
train
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 train
#
# NameError: name 'train' is not defined
